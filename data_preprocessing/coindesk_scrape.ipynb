# %%
import requests
import time
import datetime
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()
COINDESKAPIKEY = os.getenv("COINDESKAPIKEY")

# %%
import requests 

response = requests.get('https://data-api.coindesk.com/spot/v1/historical/hours',
    params={"market":"binance","instrument":"BTC-USDT","limit":10,"aggregate":1,"fill":"true","apply_mapping":"true","response_format":"JSON","to_ts":1740990845,"api_key":"4d50d36f37210bb124c685ada8aebfc92e6d384c35245c9eeee20dcf2b7377a0"},
    headers={"Content-type":"application/json; charset=UTF-8"}
)

json_response = response.json()

# %%
def get_unix_timestamp(dt):
    """Convert a datetime object to a Unix timestamp (seconds)."""
    return int(dt.timestamp())

def fetch_hourly_data_batch(to_ts, limit=1500, market="binance", instrument="BTC-USDT"):
    """
    Fetch a batch of hourly data from the Coindesk API using the proper headers
    and parameters. This function returns the data from the "Data" key.
    """
    url = "https://data-api.coindesk.com/spot/v1/historical/hours"
    params = {
        "market": market,
        "instrument": instrument,
        "limit": limit,
        "aggregate": 1,           # hourly intervals
        "fill": "true",
        "apply_mapping": "true",
        "response_format": "JSON",
        "to_ts": to_ts,
        "api_key": COINDESKAPIKEY
    }
    headers = {"Content-type": "application/json; charset=UTF-8"}
    
    response = requests.get(url, params=params, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    data = response.json()
    # Return the array of records from the "Data" key per the schema
    return data.get("Data", [])

def fetch_hourly_data_npages():
    """
    Paginate backwards using the to_ts parameter for a limited number of pages.
    Here, we limit the calls to 3 pages. The pagination uses the "TIMESTAMP" field.
    """
    # Set the end time to now (UTC)
    end_dt = datetime.datetime.utcnow()
    end_ts = get_unix_timestamp(end_dt)
    print("End timestamp:", end_ts)
    
    all_records = []
    current_to_ts = end_ts
    max_pages = 10  # Limit to 6 API calls
    page_count = 0

    while page_count < max_pages:
        batch_data = fetch_hourly_data_batch(to_ts=current_to_ts)
        
        if not batch_data:
            print("No more data returned. Stopping pagination.")
            break
        
        all_records.extend(batch_data)
        page_count += 1
        
        # Using the first element as the earliest record based on the JSON schema
        earliest_record = batch_data[0]
        print("Earliest record on page:", earliest_record)
        earliest_timestamp = int(earliest_record["TIMESTAMP"])
        
        print(f"Page {page_count} retrieved, earliest timestamp in batch: {earliest_timestamp}")
        
        # Set the new to_ts to one hour before the earliest timestamp to avoid duplicates
        current_to_ts = earliest_timestamp - 3600
        time.sleep(1)  # Pause to avoid rate limiting
    
    df = pd.DataFrame(all_records)
    
    if df.empty:
        print("No data retrieved.")
    else:
        # Verify that the 'TIMESTAMP' column exists
        if "TIMESTAMP" not in df.columns:
            print("ERROR: The DataFrame does not have a 'TIMESTAMP' column. Columns are:", df.columns)
        else:
            # Convert the TIMESTAMP column to a datetime for easier interpretation
            df["datetime"] = pd.to_datetime(df["TIMESTAMP"], unit='s', utc=True)
            df.sort_values(by="datetime", inplace=True)
    
    return df

# %%
# Execute and display results
df_prices = fetch_hourly_data_npages()
if not df_prices.empty:
    print("Fetched data shape:", df_prices.shape)
    display(df_prices.head())
else:
    print("No data retrieved.")
# Out:
# End timestamp: 1743657464
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1738260000, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 105300.01, 'HIGH': 105583.39, 'LOW': 104762.59, 'CLOSE': 105578.95, 'FIRST_TRADE_TIMESTAMP': 1738260000, 'LAST_TRADE_TIMESTAMP': 1738263599, 'FIRST_TRADE_PRICE': 105300.01, 'HIGH_TRADE_PRICE': 105583.39, 'HIGH_TRADE_TIMESTAMP': 1738263591, 'LOW_TRADE_PRICE': 104762.59, 'LOW_TRADE_TIMESTAMP': 1738261741, 'LAST_TRADE_PRICE': 105578.95, 'TOTAL_TRADES': 196049, 'TOTAL_TRADES_BUY': 94803, 'TOTAL_TRADES_SELL': 101246, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 669.46961, 'QUOTE_VOLUME': 70447605.273754, 'VOLUME_BUY': 341.90979, 'QUOTE_VOLUME_BUY': 35981051.4448385, 'VOLUME_SELL': 327.55982, 'QUOTE_VOLUME_SELL': 34466553.8289155, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 1 retrieved, earliest timestamp in batch: 1738260000
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1732860000, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 96153.86, 'HIGH': 96358, 'LOW': 95997.85, 'CLOSE': 96266.19, 'FIRST_TRADE_TIMESTAMP': 1732860000, 'LAST_TRADE_TIMESTAMP': 1732863597, 'FIRST_TRADE_PRICE': 96153.86, 'HIGH_TRADE_PRICE': 96358, 'HIGH_TRADE_TIMESTAMP': 1732860593, 'LOW_TRADE_PRICE': 95997.85, 'LOW_TRADE_TIMESTAMP': 1732860931, 'LAST_TRADE_PRICE': 96266.19, 'TOTAL_TRADES': 130124, 'TOTAL_TRADES_BUY': 62027, 'TOTAL_TRADES_SELL': 68097, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 626.0859, 'QUOTE_VOLUME': 60213173.9555719, 'VOLUME_BUY': 307.28807, 'QUOTE_VOLUME_BUY': 29554554.1864098, 'VOLUME_SELL': 318.79783, 'QUOTE_VOLUME_SELL': 30658619.7691621, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 2 retrieved, earliest timestamp in batch: 1732860000
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1727460000, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 65915.61, 'HIGH': 65929.02, 'LOW': 65524, 'CLOSE': 65876.42, 'FIRST_TRADE_TIMESTAMP': 1727460000, 'LAST_TRADE_TIMESTAMP': 1727463599, 'FIRST_TRADE_PRICE': 65915.61, 'HIGH_TRADE_PRICE': 65929.02, 'HIGH_TRADE_TIMESTAMP': 1727460085, 'LOW_TRADE_PRICE': 65524, 'LOW_TRADE_TIMESTAMP': 1727461880, 'LAST_TRADE_PRICE': 65876.42, 'TOTAL_TRADES': 118273, 'TOTAL_TRADES_BUY': 59377, 'TOTAL_TRADES_SELL': 58896, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 612.44352, 'QUOTE_VOLUME': 40246195.0946226, 'VOLUME_BUY': 297.68316, 'QUOTE_VOLUME_BUY': 19563205.4469784, 'VOLUME_SELL': 314.76036, 'QUOTE_VOLUME_SELL': 20682989.6476442, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 3 retrieved, earliest timestamp in batch: 1727460000
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1722060000, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 67895.21, 'HIGH': 68094.03, 'LOW': 67886.46, 'CLOSE': 68092.89, 'FIRST_TRADE_TIMESTAMP': 1722060000, 'LAST_TRADE_TIMESTAMP': 1722063599, 'FIRST_TRADE_PRICE': 67895.21, 'HIGH_TRADE_PRICE': 68094.03, 'HIGH_TRADE_TIMESTAMP': 1722063546, 'LOW_TRADE_PRICE': 67886.46, 'LOW_TRADE_TIMESTAMP': 1722060603, 'LAST_TRADE_PRICE': 68092.89, 'TOTAL_TRADES': 23601, 'TOTAL_TRADES_BUY': 13779, 'TOTAL_TRADES_SELL': 9822, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 552.14178, 'QUOTE_VOLUME': 37545303.5903743, 'VOLUME_BUY': 323.30504, 'QUOTE_VOLUME_BUY': 21984697.1545134, 'VOLUME_SELL': 228.83674, 'QUOTE_VOLUME_SELL': 15560606.4358609, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 4 retrieved, earliest timestamp in batch: 1722060000
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1716660000, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 69065.14, 'HIGH': 69234, 'LOW': 69065.14, 'CLOSE': 69213.2, 'FIRST_TRADE_TIMESTAMP': 1716660000, 'LAST_TRADE_TIMESTAMP': 1716663599, 'FIRST_TRADE_PRICE': 69065.15, 'HIGH_TRADE_PRICE': 69234, 'HIGH_TRADE_TIMESTAMP': 1716661151, 'LOW_TRADE_PRICE': 69065.14, 'LOW_TRADE_TIMESTAMP': 1716660017, 'LAST_TRADE_PRICE': 69213.2, 'TOTAL_TRADES': 22844, 'TOTAL_TRADES_BUY': 9605, 'TOTAL_TRADES_SELL': 13239, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 373.59442, 'QUOTE_VOLUME': 25840510.6675932, 'VOLUME_BUY': 166.69664, 'QUOTE_VOLUME_BUY': 11529708.95674, 'VOLUME_SELL': 206.89778, 'QUOTE_VOLUME_SELL': 14310801.7108532, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 5 retrieved, earliest timestamp in batch: 1716660000
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1711260000, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 64304.57, 'HIGH': 64418.54, 'LOW': 64086.19, 'CLOSE': 64218.94, 'FIRST_TRADE_TIMESTAMP': 1711260000, 'LAST_TRADE_TIMESTAMP': 1711263599, 'FIRST_TRADE_PRICE': 64304.57, 'HIGH_TRADE_PRICE': 64418.54, 'HIGH_TRADE_TIMESTAMP': 1711260948, 'LOW_TRADE_PRICE': 64086.19, 'LOW_TRADE_TIMESTAMP': 1711262781, 'LAST_TRADE_PRICE': 64218.94, 'TOTAL_TRADES': 56817, 'TOTAL_TRADES_BUY': 20043, 'TOTAL_TRADES_SELL': 36774, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 522.18944, 'QUOTE_VOLUME': 33541372.7482833, 'VOLUME_BUY': 221.79645, 'QUOTE_VOLUME_BUY': 14246818.2902883, 'VOLUME_SELL': 300.39299, 'QUOTE_VOLUME_SELL': 19294554.457995, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 6 retrieved, earliest timestamp in batch: 1711260000
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1705860000, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 41678, 'HIGH': 41729.77, 'LOW': 41627, 'CLOSE': 41681.09, 'FIRST_TRADE_TIMESTAMP': 1705860000, 'LAST_TRADE_TIMESTAMP': 1705863599, 'FIRST_TRADE_PRICE': 41678, 'HIGH_TRADE_PRICE': 41729.77, 'HIGH_TRADE_TIMESTAMP': 1705861085, 'LOW_TRADE_PRICE': 41627, 'LOW_TRADE_TIMESTAMP': 1705860635, 'LAST_TRADE_PRICE': 41681.09, 'TOTAL_TRADES': 24610, 'TOTAL_TRADES_BUY': 10204, 'TOTAL_TRADES_SELL': 14406, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 467.73485, 'QUOTE_VOLUME': 19499796.151109, 'VOLUME_BUY': 224.31273, 'QUOTE_VOLUME_BUY': 9351182.8957584, 'VOLUME_SELL': 243.42212, 'QUOTE_VOLUME_SELL': 10148613.2553506, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 7 retrieved, earliest timestamp in batch: 1705860000
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1700460000, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 37132.88, 'HIGH': 37200, 'LOW': 37060.4, 'CLOSE': 37182.62, 'FIRST_TRADE_TIMESTAMP': 1700460000, 'LAST_TRADE_TIMESTAMP': 1700463599, 'FIRST_TRADE_PRICE': 37132.87, 'HIGH_TRADE_PRICE': 37200, 'HIGH_TRADE_TIMESTAMP': 1700463300, 'LOW_TRADE_PRICE': 37060.4, 'LOW_TRADE_TIMESTAMP': 1700462133, 'LAST_TRADE_PRICE': 37182.62, 'TOTAL_TRADES': 28334, 'TOTAL_TRADES_BUY': 13065, 'TOTAL_TRADES_SELL': 15269, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 622.22305, 'QUOTE_VOLUME': 23112321.9690706, 'VOLUME_BUY': 293.53594, 'QUOTE_VOLUME_BUY': 10903239.5100112, 'VOLUME_SELL': 328.68711, 'QUOTE_VOLUME_SELL': 12209082.4590594, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 8 retrieved, earliest timestamp in batch: 1700460000
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1695060000, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 26760.49, 'HIGH': 26842.93, 'LOW': 26631, 'CLOSE': 26710, 'FIRST_TRADE_TIMESTAMP': 1695060000, 'LAST_TRADE_TIMESTAMP': 1695063599, 'FIRST_TRADE_PRICE': 26768.42, 'HIGH_TRADE_PRICE': 26842.93, 'HIGH_TRADE_TIMESTAMP': 1695060949, 'LOW_TRADE_PRICE': 26631, 'LOW_TRADE_TIMESTAMP': 1695062491, 'LAST_TRADE_PRICE': 26710, 'TOTAL_TRADES': 44104, 'TOTAL_TRADES_BUY': 20591, 'TOTAL_TRADES_SELL': 23513, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 2274.88146, 'QUOTE_VOLUME': 60811139.1406856, 'VOLUME_BUY': 1077.39322, 'QUOTE_VOLUME_BUY': 28804367.866511, 'VOLUME_SELL': 1197.48824, 'QUOTE_VOLUME_SELL': 32006771.2741746, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 9 retrieved, earliest timestamp in batch: 1695060000
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1689660000, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 30052.22, 'HIGH': 30097.09, 'LOW': 29921.54, 'CLOSE': 29988.62, 'FIRST_TRADE_TIMESTAMP': 1689660000, 'LAST_TRADE_TIMESTAMP': 1689663599, 'FIRST_TRADE_PRICE': 30052.23, 'HIGH_TRADE_PRICE': 30097.09, 'HIGH_TRADE_TIMESTAMP': 1689661503, 'LOW_TRADE_PRICE': 29921.54, 'LOW_TRADE_TIMESTAMP': 1689662775, 'LAST_TRADE_PRICE': 29988.62, 'TOTAL_TRADES': 40673, 'TOTAL_TRADES_BUY': 17093, 'TOTAL_TRADES_SELL': 23580, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 1388.9038, 'QUOTE_VOLUME': 41675613.3083125, 'VOLUME_BUY': 610.27999, 'QUOTE_VOLUME_BUY': 18312443.0353777, 'VOLUME_SELL': 778.62381, 'QUOTE_VOLUME_SELL': 23363170.2729348, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 10 retrieved, earliest timestamp in batch: 1689660000
# Fetched data shape: (15000, 36)
#        UNIT   TIMESTAMP TYPE   MARKET INSTRUMENT MAPPED_INSTRUMENT BASE QUOTE  \
# 13500  HOUR  1689660000  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 13501  HOUR  1689663600  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 13502  HOUR  1689667200  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 13503  HOUR  1689670800  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 13504  HOUR  1689674400  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
#
#        BASE_ID  QUOTE_ID  ... TOTAL_TRADES_UNKNOWN      VOLUME  QUOTE_VOLUME  \
# 13500        1         7  ...                    0  1388.90380  4.167561e+07
# 13501        1         7  ...                    0  1151.28365  3.453828e+07
# 13502        1         7  ...                    0  1610.96253  4.832142e+07
# 13503        1         7  ...                    0   784.77762  2.353937e+07
# 13504        1         7  ...                    0  1128.41237  3.381184e+07
#
#        VOLUME_BUY  QUOTE_VOLUME_BUY  VOLUME_SELL  QUOTE_VOLUME_SELL  \
# 13500   610.27999      1.831244e+07    778.62381       2.336317e+07
# 13501   589.87374      1.769808e+07    561.40991       1.684020e+07
# 13502   733.31672      2.199763e+07    877.64581       2.632379e+07
# 13503   341.89704      1.025509e+07    442.88058       1.328428e+07
# 13504   530.21864      1.588681e+07    598.19373       1.792503e+07
#
#        VOLUME_UNKNOWN  QUOTE_VOLUME_UNKNOWN                  datetime
# 13500               0                     0 2023-07-18 06:00:00+00:00
# 13501               0                     0 2023-07-18 07:00:00+00:00
# 13502               0                     0 2023-07-18 08:00:00+00:00
# 13503               0                     0 2023-07-18 09:00:00+00:00
# 13504               0                     0 2023-07-18 10:00:00+00:00
#
# [5 rows x 36 columns]

# %%
# Save to CSV if desired
df_prices.to_csv("../data/raw/btc_usdt_hourly.csv", index=False)
