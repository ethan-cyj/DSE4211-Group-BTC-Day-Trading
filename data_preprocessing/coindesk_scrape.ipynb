# %%
import requests
import time
import datetime
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()
COINDESKAPIKEY = os.getenv("COINDESKAPIKEY")

# %%
import requests 

response = requests.get('https://data-api.coindesk.com/spot/v1/historical/hours',
    params={"market":"binance","instrument":"BTC-USDT","limit":10,"aggregate":1,"fill":"true","apply_mapping":"true","response_format":"JSON","to_ts":1740990845,"api_key":"4d50d36f37210bb124c685ada8aebfc92e6d384c35245c9eeee20dcf2b7377a0"},
    headers={"Content-type":"application/json; charset=UTF-8"}
)

json_response = response.json()

# %%
def get_unix_timestamp(dt):
    """Convert a datetime object to a Unix timestamp (seconds)."""
    return int(dt.timestamp())

def fetch_hourly_data_batch(to_ts, limit=1500, market="binance", instrument="BTC-USDT"):
    """
    Fetch a batch of hourly data from the Coindesk API using the proper headers
    and parameters. This function returns the data from the "Data" key.
    """
    url = "https://data-api.coindesk.com/spot/v1/historical/hours"
    params = {
        "market": market,
        "instrument": instrument,
        "limit": limit,
        "aggregate": 1,           # hourly intervals
        "fill": "true",
        "apply_mapping": "true",
        "response_format": "JSON",
        "to_ts": to_ts,
        "api_key": COINDESKAPIKEY
    }
    headers = {"Content-type": "application/json; charset=UTF-8"}
    
    response = requests.get(url, params=params, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    data = response.json()
    # Return the array of records from the "Data" key per the schema
    return data.get("Data", [])

def fetch_hourly_data_npages():
    """
    Paginate backwards using the to_ts parameter for a limited number of pages.
    Here, we limit the calls to 3 pages. The pagination uses the "TIMESTAMP" field.
    """
    # Set the end time to now (UTC)
    end_dt = datetime.datetime.utcnow()
    end_ts = get_unix_timestamp(end_dt)
    print("End timestamp:", end_ts)
    
    all_records = []
    current_to_ts = end_ts
    max_pages = 9  # Limit to 6 API calls
    page_count = 0

    while page_count < max_pages:
        batch_data = fetch_hourly_data_batch(to_ts=current_to_ts)
        
        if not batch_data:
            print("No more data returned. Stopping pagination.")
            break
        
        all_records.extend(batch_data)
        page_count += 1
        
        # Using the first element as the earliest record based on the JSON schema
        earliest_record = batch_data[0]
        print("Earliest record on page:", earliest_record)
        earliest_timestamp = int(earliest_record["TIMESTAMP"])
        
        print(f"Page {page_count} retrieved, earliest timestamp in batch: {earliest_timestamp}")
        
        # Set the new to_ts to one hour before the earliest timestamp to avoid duplicates
        current_to_ts = earliest_timestamp - 3600
        time.sleep(1)  # Pause to avoid rate limiting
    
    df = pd.DataFrame(all_records)
    
    if df.empty:
        print("No data retrieved.")
    else:
        # Verify that the 'TIMESTAMP' column exists
        if "TIMESTAMP" not in df.columns:
            print("ERROR: The DataFrame does not have a 'TIMESTAMP' column. Columns are:", df.columns)
        else:
            # Convert the TIMESTAMP column to a datetime for easier interpretation
            df["datetime"] = pd.to_datetime(df["TIMESTAMP"], unit='s', utc=True)
            df.sort_values(by="datetime", inplace=True)
    
    return df

# %%
# Execute and display results
df_prices = fetch_hourly_data_npages()
if not df_prices.empty:
    print("Fetched data shape:", df_prices.shape)
    display(df_prices.head())
else:
    print("No data retrieved.")
# Out:
# End timestamp: 1743102654
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1737705600, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 105046.8, 'HIGH': 105650, 'LOW': 104922.41, 'CLOSE': 105500.76, 'FIRST_TRADE_TIMESTAMP': 1737705600, 'LAST_TRADE_TIMESTAMP': 1737709199, 'FIRST_TRADE_PRICE': 105046.79, 'HIGH_TRADE_PRICE': 105650, 'HIGH_TRADE_TIMESTAMP': 1737707419, 'LOW_TRADE_PRICE': 104922.41, 'LOW_TRADE_TIMESTAMP': 1737705928, 'LAST_TRADE_PRICE': 105500.76, 'TOTAL_TRADES': 167520, 'TOTAL_TRADES_BUY': 80877, 'TOTAL_TRADES_SELL': 86643, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 938.64874, 'QUOTE_VOLUME': 98896263.6909673, 'VOLUME_BUY': 485.69586, 'QUOTE_VOLUME_BUY': 51176193.8757169, 'VOLUME_SELL': 452.95288, 'QUOTE_VOLUME_SELL': 47720069.8152504, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 1 retrieved, earliest timestamp in batch: 1737705600
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1732305600, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 99079.74, 'HIGH': 99449, 'LOW': 98924.01, 'CLOSE': 99163.99, 'FIRST_TRADE_TIMESTAMP': 1732305600, 'LAST_TRADE_TIMESTAMP': 1732309199, 'FIRST_TRADE_PRICE': 99079.74, 'HIGH_TRADE_PRICE': 99449, 'HIGH_TRADE_TIMESTAMP': 1732306626, 'LOW_TRADE_PRICE': 98924.01, 'LOW_TRADE_TIMESTAMP': 1732305826, 'LAST_TRADE_PRICE': 99163.99, 'TOTAL_TRADES': 362364, 'TOTAL_TRADES_BUY': 206146, 'TOTAL_TRADES_SELL': 156218, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 1805.05499, 'QUOTE_VOLUME': 178965213.182296, 'VOLUME_BUY': 953.45519, 'QUOTE_VOLUME_BUY': 94524785.8634051, 'VOLUME_SELL': 851.5998, 'QUOTE_VOLUME_SELL': 84440427.3204311, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 2 retrieved, earliest timestamp in batch: 1732305600
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1726905600, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 63091.02, 'HIGH': 63120, 'LOW': 63000, 'CLOSE': 63028, 'FIRST_TRADE_TIMESTAMP': 1726905600, 'LAST_TRADE_TIMESTAMP': 1726909199, 'FIRST_TRADE_PRICE': 63091.02, 'HIGH_TRADE_PRICE': 63120, 'HIGH_TRADE_TIMESTAMP': 1726905731, 'LOW_TRADE_PRICE': 63000, 'LOW_TRADE_TIMESTAMP': 1726907994, 'LAST_TRADE_PRICE': 63028, 'TOTAL_TRADES': 35836, 'TOTAL_TRADES_BUY': 15900, 'TOTAL_TRADES_SELL': 19936, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 364.87888, 'QUOTE_VOLUME': 23005854.4784564, 'VOLUME_BUY': 99.00687, 'QUOTE_VOLUME_BUY': 6242389.088604, 'VOLUME_SELL': 265.87201, 'QUOTE_VOLUME_SELL': 16763465.3898524, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 3 retrieved, earliest timestamp in batch: 1726905600
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1721505600, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 67224, 'HIGH': 67430.01, 'LOW': 67223.99, 'CLOSE': 67339.28, 'FIRST_TRADE_TIMESTAMP': 1721505600, 'LAST_TRADE_TIMESTAMP': 1721509199, 'FIRST_TRADE_PRICE': 67224, 'HIGH_TRADE_PRICE': 67430.01, 'HIGH_TRADE_TIMESTAMP': 1721507763, 'LOW_TRADE_PRICE': 67223.99, 'LOW_TRADE_TIMESTAMP': 1721505648, 'LAST_TRADE_PRICE': 67339.28, 'TOTAL_TRADES': 24754, 'TOTAL_TRADES_BUY': 13180, 'TOTAL_TRADES_SELL': 11574, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 289.57206, 'QUOTE_VOLUME': 19498267.4430774, 'VOLUME_BUY': 139.86094, 'QUOTE_VOLUME_BUY': 9416855.116548, 'VOLUME_SELL': 149.71112, 'QUOTE_VOLUME_SELL': 10081412.3265294, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 4 retrieved, earliest timestamp in batch: 1721505600
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1716105600, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 67324.44, 'HIGH': 67339.91, 'LOW': 67100, 'CLOSE': 67160.01, 'FIRST_TRADE_TIMESTAMP': 1716105600, 'LAST_TRADE_TIMESTAMP': 1716109199, 'FIRST_TRADE_PRICE': 67324.44, 'HIGH_TRADE_PRICE': 67339.91, 'HIGH_TRADE_TIMESTAMP': 1716105619, 'LOW_TRADE_PRICE': 67100, 'LOW_TRADE_TIMESTAMP': 1716108053, 'LAST_TRADE_PRICE': 67160.01, 'TOTAL_TRADES': 25545, 'TOTAL_TRADES_BUY': 11624, 'TOTAL_TRADES_SELL': 13921, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 453.96065, 'QUOTE_VOLUME': 30511111.6021848, 'VOLUME_BUY': 204.7246, 'QUOTE_VOLUME_BUY': 13759643.2215574, 'VOLUME_SELL': 249.23605, 'QUOTE_VOLUME_SELL': 16751468.3806274, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 5 retrieved, earliest timestamp in batch: 1716105600
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1710705600, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 68536.73, 'HIGH': 68666, 'LOW': 68205.15, 'CLOSE': 68269.06, 'FIRST_TRADE_TIMESTAMP': 1710705600, 'LAST_TRADE_TIMESTAMP': 1710709199, 'FIRST_TRADE_PRICE': 68536.73, 'HIGH_TRADE_PRICE': 68666, 'HIGH_TRADE_TIMESTAMP': 1710706541, 'LOW_TRADE_PRICE': 68205.15, 'LOW_TRADE_TIMESTAMP': 1710709062, 'LAST_TRADE_PRICE': 68269.06, 'TOTAL_TRADES': 56109, 'TOTAL_TRADES_BUY': 26671, 'TOTAL_TRADES_SELL': 29438, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 1200.74147, 'QUOTE_VOLUME': 82203201.4561284, 'VOLUME_BUY': 537.56395, 'QUOTE_VOLUME_BUY': 36810366.0991987, 'VOLUME_SELL': 663.17752, 'QUOTE_VOLUME_SELL': 45392835.3569297, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 6 retrieved, earliest timestamp in batch: 1710705600
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1705305600, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 42714.78, 'HIGH': 42775, 'LOW': 42641.1, 'CLOSE': 42680.44, 'FIRST_TRADE_TIMESTAMP': 1705305600, 'LAST_TRADE_TIMESTAMP': 1705309199, 'FIRST_TRADE_PRICE': 42718.91, 'HIGH_TRADE_PRICE': 42775, 'HIGH_TRADE_TIMESTAMP': 1705308052, 'LOW_TRADE_PRICE': 42641.1, 'LOW_TRADE_TIMESTAMP': 1705306201, 'LAST_TRADE_PRICE': 42680.44, 'TOTAL_TRADES': 42019, 'TOTAL_TRADES_BUY': 18406, 'TOTAL_TRADES_SELL': 23613, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 1082.69198, 'QUOTE_VOLUME': 46230418.6672828, 'VOLUME_BUY': 556.22902, 'QUOTE_VOLUME_BUY': 23750824.4086307, 'VOLUME_SELL': 526.46296, 'QUOTE_VOLUME_SELL': 22479594.2586521, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 7 retrieved, earliest timestamp in batch: 1705305600
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1699905600, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 36844.98, 'HIGH': 36875, 'LOW': 36743.74, 'CLOSE': 36785.18, 'FIRST_TRADE_TIMESTAMP': 1699905600, 'LAST_TRADE_TIMESTAMP': 1699909199, 'FIRST_TRADE_PRICE': 36844.98, 'HIGH_TRADE_PRICE': 36875, 'HIGH_TRADE_TIMESTAMP': 1699905913, 'LOW_TRADE_PRICE': 36743.74, 'LOW_TRADE_TIMESTAMP': 1699909171, 'LAST_TRADE_PRICE': 36785.18, 'TOTAL_TRADES': 42382, 'TOTAL_TRADES_BUY': 20813, 'TOTAL_TRADES_SELL': 21569, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 866.16686, 'QUOTE_VOLUME': 31888973.6421184, 'VOLUME_BUY': 400.89224, 'QUOTE_VOLUME_BUY': 14758647.9249716, 'VOLUME_SELL': 465.27462, 'QUOTE_VOLUME_SELL': 17130325.7171468, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 8 retrieved, earliest timestamp in batch: 1699905600
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1694505600, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 25822.71, 'HIGH': 25871.06, 'LOW': 25735.29, 'CLOSE': 25766.93, 'FIRST_TRADE_TIMESTAMP': 1694505600, 'LAST_TRADE_TIMESTAMP': 1694509199, 'FIRST_TRADE_PRICE': 25822.72, 'HIGH_TRADE_PRICE': 25871.06, 'HIGH_TRADE_TIMESTAMP': 1694506558, 'LOW_TRADE_PRICE': 25735.29, 'LOW_TRADE_TIMESTAMP': 1694508982, 'LAST_TRADE_PRICE': 25766.93, 'TOTAL_TRADES': 28391, 'TOTAL_TRADES_BUY': 12051, 'TOTAL_TRADES_SELL': 16340, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 1893.94969, 'QUOTE_VOLUME': 48877650.1567237, 'VOLUME_BUY': 846.27631, 'QUOTE_VOLUME_BUY': 21845187.2756759, 'VOLUME_SELL': 1047.67338, 'QUOTE_VOLUME_SELL': 27032462.8810478, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 9 retrieved, earliest timestamp in batch: 1694505600
# Fetched data shape: (13500, 36)
#        UNIT   TIMESTAMP TYPE   MARKET INSTRUMENT MAPPED_INSTRUMENT BASE QUOTE  \
# 12000  HOUR  1694505600  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 12001  HOUR  1694509200  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 12002  HOUR  1694512800  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 12003  HOUR  1694516400  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 12004  HOUR  1694520000  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
#
#        BASE_ID  QUOTE_ID  ... TOTAL_TRADES_UNKNOWN      VOLUME  QUOTE_VOLUME  \
# 12000        1         7  ...                    0  1893.94969  4.887765e+07
# 12001        1         7  ...                    0  1455.35759  3.755783e+07
# 12002        1         7  ...                    0  6661.53232  1.741119e+08
# 12003        1         7  ...                    0  2116.39977  5.524047e+07
# 12004        1         7  ...                    0  1686.56984  4.410999e+07
#
#        VOLUME_BUY  QUOTE_VOLUME_BUY  VOLUME_SELL  QUOTE_VOLUME_SELL  \
# 12000   846.27631      2.184519e+07   1047.67338       2.703246e+07
# 12001   719.08619      1.855834e+07    736.27140       1.899949e+07
# 12002  3444.38486      9.002064e+07   3217.14746       8.409124e+07
# 12003   923.61832      2.410964e+07   1192.78145       3.113083e+07
# 12004   753.80994      1.971777e+07    932.75990       2.439221e+07
#
#        VOLUME_UNKNOWN  QUOTE_VOLUME_UNKNOWN                  datetime
# 12000               0                     0 2023-09-12 08:00:00+00:00
# 12001               0                     0 2023-09-12 09:00:00+00:00
# 12002               0                     0 2023-09-12 10:00:00+00:00
# 12003               0                     0 2023-09-12 11:00:00+00:00
# 12004               0                     0 2023-09-12 12:00:00+00:00
#
# [5 rows x 36 columns]

# %%
# Save to CSV if desired
df_prices.to_csv("../data/raw/btc_usdt_hourly.csv", index=False)
