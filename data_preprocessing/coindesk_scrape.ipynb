# %%
import requests
import time
import datetime
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()
COINDESKAPIKEY = os.getenv("COINDESKAPIKEY")

# %%
import requests 

response = requests.get('https://data-api.coindesk.com/spot/v1/historical/hours',
    params={"market":"binance","instrument":"BTC-USDT","limit":10,"aggregate":1,"fill":"true","apply_mapping":"true","response_format":"JSON","to_ts":1740990845,"api_key":"4d50d36f37210bb124c685ada8aebfc92e6d384c35245c9eeee20dcf2b7377a0"},
    headers={"Content-type":"application/json; charset=UTF-8"}
)

json_response = response.json()

# %%
def get_unix_timestamp(dt):
    """Convert a datetime object to a Unix timestamp (seconds)."""
    return int(dt.timestamp())

def fetch_hourly_data_batch(to_ts, limit=1500, market="binance", instrument="BTC-USDT"):
    """
    Fetch a batch of hourly data from the Coindesk API using the proper headers
    and parameters. This function returns the data from the "Data" key.
    """
    url = "https://data-api.coindesk.com/spot/v1/historical/hours"
    params = {
        "market": market,
        "instrument": instrument,
        "limit": limit,
        "aggregate": 1,           # hourly intervals
        "fill": "true",
        "apply_mapping": "true",
        "response_format": "JSON",
        "to_ts": to_ts,
        "api_key": COINDESKAPIKEY
    }
    headers = {"Content-type": "application/json; charset=UTF-8"}
    
    response = requests.get(url, params=params, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    data = response.json()
    # Return the array of records from the "Data" key per the schema
    return data.get("Data", [])

def fetch_hourly_data_npages():
    """
    Paginate backwards using the to_ts parameter for a limited number of pages.
    Here, we limit the calls to 3 pages. The pagination uses the "TIMESTAMP" field.
    """
    # Set the end time to now (UTC)
    end_dt = datetime.datetime.utcnow()
    end_ts = get_unix_timestamp(end_dt)
    print("End timestamp:", end_ts)
    
    all_records = []
    current_to_ts = end_ts
    max_pages = 6  # Limit to 6 API calls
    page_count = 0

    while page_count < max_pages:
        batch_data = fetch_hourly_data_batch(to_ts=current_to_ts)
        
        if not batch_data:
            print("No more data returned. Stopping pagination.")
            break
        
        all_records.extend(batch_data)
        page_count += 1
        
        # Using the first element as the earliest record based on the JSON schema
        earliest_record = batch_data[0]
        print("Earliest record on page:", earliest_record)
        earliest_timestamp = int(earliest_record["TIMESTAMP"])
        
        print(f"Page {page_count} retrieved, earliest timestamp in batch: {earliest_timestamp}")
        
        # Set the new to_ts to one hour before the earliest timestamp to avoid duplicates
        current_to_ts = earliest_timestamp - 3600
        time.sleep(1)  # Pause to avoid rate limiting
    
    df = pd.DataFrame(all_records)
    
    if df.empty:
        print("No data retrieved.")
    else:
        # Verify that the 'TIMESTAMP' column exists
        if "TIMESTAMP" not in df.columns:
            print("ERROR: The DataFrame does not have a 'TIMESTAMP' column. Columns are:", df.columns)
        else:
            # Convert the TIMESTAMP column to a datetime for easier interpretation
            df["datetime"] = pd.to_datetime(df["TIMESTAMP"], unit='s', utc=True)
            df.sort_values(by="datetime", inplace=True)
    
    return df

# %%
# Execute and display results
df_prices = fetch_hourly_data_npages()
if not df_prices.empty:
    print("Fetched data shape:", df_prices.shape)
    display(df_prices.head())
else:
    print("No data retrieved.")
# Out:
# End timestamp: 1741028246
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1735628400, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 92816, 'HIGH': 92910.03, 'LOW': 92770, 'CLOSE': 92860.75, 'FIRST_TRADE_TIMESTAMP': 1735628400, 'LAST_TRADE_TIMESTAMP': 1735631999, 'FIRST_TRADE_PRICE': 92816, 'HIGH_TRADE_PRICE': 92910.03, 'HIGH_TRADE_TIMESTAMP': 1735631761, 'LOW_TRADE_PRICE': 92770, 'LOW_TRADE_TIMESTAMP': 1735628463, 'LAST_TRADE_PRICE': 92860.75, 'TOTAL_TRADES': 61503, 'TOTAL_TRADES_BUY': 33711, 'TOTAL_TRADES_SELL': 27792, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 485.23565, 'QUOTE_VOLUME': 45059075.3090525, 'VOLUME_BUY': 282.11043, 'QUOTE_VOLUME_BUY': 26197557.4775072, 'VOLUME_SELL': 203.12522, 'QUOTE_VOLUME_SELL': 18861517.8315453, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 1 retrieved, earliest timestamp in batch: 1735628400
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1730228400, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 73170.01, 'HIGH': 73620.12, 'LOW': 72504.03, 'CLOSE': 72536.16, 'FIRST_TRADE_TIMESTAMP': 1730228400, 'LAST_TRADE_TIMESTAMP': 1730231999, 'FIRST_TRADE_PRICE': 73170, 'HIGH_TRADE_PRICE': 73620.12, 'HIGH_TRADE_TIMESTAMP': 1730229104, 'LOW_TRADE_PRICE': 72504.03, 'LOW_TRADE_TIMESTAMP': 1730231996, 'LAST_TRADE_PRICE': 72536.16, 'TOTAL_TRADES': 535015, 'TOTAL_TRADES_BUY': 256781, 'TOTAL_TRADES_SELL': 278234, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 4571.61324, 'QUOTE_VOLUME': 334112947.484533, 'VOLUME_BUY': 2236.85686, 'QUOTE_VOLUME_BUY': 163551020.100596, 'VOLUME_SELL': 2334.75638, 'QUOTE_VOLUME_SELL': 170561927.38322, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 2 retrieved, earliest timestamp in batch: 1730228400
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1724828400, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 59186.91, 'HIGH': 59271.82, 'LOW': 58516, 'CLOSE': 58600.98, 'FIRST_TRADE_TIMESTAMP': 1724828400, 'LAST_TRADE_TIMESTAMP': 1724831999, 'FIRST_TRADE_PRICE': 59186.91, 'HIGH_TRADE_PRICE': 59271.82, 'HIGH_TRADE_TIMESTAMP': 1724828751, 'LOW_TRADE_PRICE': 58516, 'LOW_TRADE_TIMESTAMP': 1724831940, 'LAST_TRADE_PRICE': 58600.98, 'TOTAL_TRADES': 161252, 'TOTAL_TRADES_BUY': 73300, 'TOTAL_TRADES_SELL': 87952, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 1770.51433, 'QUOTE_VOLUME': 104249428.071673, 'VOLUME_BUY': 843.53905, 'QUOTE_VOLUME_BUY': 49664259.1220718, 'VOLUME_SELL': 926.97528, 'QUOTE_VOLUME_SELL': 54585168.9495799, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 3 retrieved, earliest timestamp in batch: 1724828400
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1719428400, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 60910.02, 'HIGH': 61142, 'LOW': 60715.3, 'CLOSE': 61000.01, 'FIRST_TRADE_TIMESTAMP': 1719428400, 'LAST_TRADE_TIMESTAMP': 1719431999, 'FIRST_TRADE_PRICE': 60910.02, 'HIGH_TRADE_PRICE': 61142, 'HIGH_TRADE_TIMESTAMP': 1719431807, 'LOW_TRADE_PRICE': 60715.3, 'LOW_TRADE_TIMESTAMP': 1719429685, 'LAST_TRADE_PRICE': 61000.01, 'TOTAL_TRADES': 92076, 'TOTAL_TRADES_BUY': 37259, 'TOTAL_TRADES_SELL': 54817, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 1489.50301, 'QUOTE_VOLUME': 90706782.1913452, 'VOLUME_BUY': 839.50082, 'QUOTE_VOLUME_BUY': 51121387.5265647, 'VOLUME_SELL': 650.00219, 'QUOTE_VOLUME_SELL': 39585394.6647805, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 4 retrieved, earliest timestamp in batch: 1719428400
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1714028400, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 64288, 'HIGH': 64379.85, 'LOW': 63824.07, 'CLOSE': 64017.99, 'FIRST_TRADE_TIMESTAMP': 1714028400, 'LAST_TRADE_TIMESTAMP': 1714031999, 'FIRST_TRADE_PRICE': 64288, 'HIGH_TRADE_PRICE': 64379.85, 'HIGH_TRADE_TIMESTAMP': 1714029430, 'LOW_TRADE_PRICE': 63824.07, 'LOW_TRADE_TIMESTAMP': 1714031245, 'LAST_TRADE_PRICE': 64017.99, 'TOTAL_TRADES': 44943, 'TOTAL_TRADES_BUY': 20177, 'TOTAL_TRADES_SELL': 24766, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 951.17474, 'QUOTE_VOLUME': 60981338.3726268, 'VOLUME_BUY': 373.73777, 'QUOTE_VOLUME_BUY': 23967562.7734953, 'VOLUME_SELL': 577.43697, 'QUOTE_VOLUME_SELL': 37013775.5991315, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 5 retrieved, earliest timestamp in batch: 1714028400
# Earliest record on page: {'UNIT': 'HOUR', 'TIMESTAMP': 1708628400, 'TYPE': '954', 'MARKET': 'binance', 'INSTRUMENT': 'BTCUSDT', 'MAPPED_INSTRUMENT': 'BTC-USDT', 'BASE': 'BTC', 'QUOTE': 'USDT', 'BASE_ID': 1, 'QUOTE_ID': 7, 'TRANSFORM_FUNCTION': '', 'OPEN': 51718.81, 'HIGH': 51718.82, 'LOW': 51460.8, 'CLOSE': 51509.99, 'FIRST_TRADE_TIMESTAMP': 1708628400, 'LAST_TRADE_TIMESTAMP': 1708631999, 'FIRST_TRADE_PRICE': 51714.57, 'HIGH_TRADE_PRICE': 51718.82, 'HIGH_TRADE_TIMESTAMP': 1708628400, 'LOW_TRADE_PRICE': 51460.8, 'LOW_TRADE_TIMESTAMP': 1708630652, 'LAST_TRADE_PRICE': 51509.99, 'TOTAL_TRADES': 50652, 'TOTAL_TRADES_BUY': 27901, 'TOTAL_TRADES_SELL': 22751, 'TOTAL_TRADES_UNKNOWN': 0, 'VOLUME': 1412.76654, 'QUOTE_VOLUME': 72868289.5124112, 'VOLUME_BUY': 602.38295, 'QUOTE_VOLUME_BUY': 31063442.1066613, 'VOLUME_SELL': 810.38359, 'QUOTE_VOLUME_SELL': 41804847.4057499, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}
# Page 6 retrieved, earliest timestamp in batch: 1708628400
# Fetched data shape: (9000, 36)
#       UNIT   TIMESTAMP TYPE   MARKET INSTRUMENT MAPPED_INSTRUMENT BASE QUOTE  \
# 7500  HOUR  1708628400  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 7501  HOUR  1708632000  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 7502  HOUR  1708635600  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 7503  HOUR  1708639200  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
# 7504  HOUR  1708642800  954  binance    BTCUSDT          BTC-USDT  BTC  USDT
#
#       BASE_ID  QUOTE_ID  ... TOTAL_TRADES_UNKNOWN      VOLUME  QUOTE_VOLUME  \
# 7500        1         7  ...                    0  1412.76654  7.286829e+07
# 7501        1         7  ...                    0  3121.92839  1.618850e+08
# 7502        1         7  ...                    0  1264.97024  6.538372e+07
# 7503        1         7  ...                    0  1357.06045  6.981523e+07
# 7504        1         7  ...                    0  1038.76395  5.331609e+07
#
#       VOLUME_BUY  QUOTE_VOLUME_BUY  VOLUME_SELL  QUOTE_VOLUME_SELL  \
# 7500   602.38295      3.106344e+07    810.38359       4.180485e+07
# 7501  1779.83133      9.229998e+07   1342.09706       6.958498e+07
# 7502   667.58788      3.450595e+07    597.38236       3.087777e+07
# 7503   695.54171      3.578757e+07    661.51874       3.402766e+07
# 7504   535.06306      2.746374e+07    503.70089       2.585235e+07
#
#       VOLUME_UNKNOWN  QUOTE_VOLUME_UNKNOWN                  datetime
# 7500               0                     0 2024-02-22 19:00:00+00:00
# 7501               0                     0 2024-02-22 20:00:00+00:00
# 7502               0                     0 2024-02-22 21:00:00+00:00
# 7503               0                     0 2024-02-22 22:00:00+00:00
# 7504               0                     0 2024-02-22 23:00:00+00:00
#
# [5 rows x 36 columns]

# %%
# Save to CSV if desired
df_prices.to_csv("../data/raw/btc_usdt_hourly.csv", index=False)
