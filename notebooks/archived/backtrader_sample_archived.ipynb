# %%
# %matplotlib inline

import backtrader as bt


class MultiIndicatorStrategy(bt.Strategy):
    """
    This strategy uses pre-computed technical indicators from our custom data feed:
      - 8, 13, 21 EMA for trend signals,
      - MACD (with its Signal Line) for momentum confirmation,
      - RSI for momentum/overbought filtering.
    
    Entry (Buy) Condition:
      - EMA_8 is above both EMA_13 and EMA_21,
      - MACD is positive,
      - RSI is below 70.
      
    Exit (Sell) Condition:
      - EMA_8 falls below both EMA_13 and EMA_21.
    """
    
    def __init__(self):
        # Use the pre-calculated indicators from the custom feed.
        self.ema8 = self.data.EMA_8
        self.ema13 = self.data.EMA_13
        self.ema21 = self.data.EMA_21
        
        self.macd = self.data.MACD
        self.signal_line = self.data.Signal_Line  # Not used in the entry, but available
        
        self.rsi = self.data.RSI_14

    def next(self):
        # Check if we are in the market
        if not self.position:
            # Long Entry:
            # - 8 EMA is above both 13 and 21 EMAs,
            # - MACD is positive,
            # - RSI is below 70.
            if (self.ema8[0] > self.ema13[0] and self.ema8[0] > self.ema21[0]
                and self.macd[0] > 0 and self.rsi[0] < 70
                ):
                self.buy()
                self.log("BUY CREATE, Price: {:.2f}".format(self.data.close[0]))
        else:
            # Exit (sell) when 8 EMA falls below both 13 and 21 EMAs.
            if self.ema8[0] < self.ema13[0] and self.ema8[0] < self.ema21[0]:
                self.close()
                self.log("SELL CREATE, Price: {:.2f}".format(self.data.close[0]))

    def log(self, txt, dt=None):
        """ Logging function for this strategy """
        dt = dt or self.datas[0].datetime.date(0)
        print(f"{dt.isoformat()} - {txt}")

# %%
import pandas as pd

# Create a custom data feed class that maps your DataFrame columns.
class CustomPandasData(bt.feeds.PandasData):
    # Define additional lines that your DataFrame contains.
    lines = (
        'return', 'log_return', 'hourly_volatility',
        'EMA_8', 'EMA_13', 'EMA_21', 'EMA_signal',
        'EMA_short', 'EMA_long',
        'MACD', 'Signal_Line', 'MACD_Hist',
        'SMA20', 'STD20', 'Upper_BB', 'Lower_BB',
        'RSI_14'
    )
    # Map the DataFrame columns to Backtrader parameters.
    params = (
        ('datetime', None),        # use DataFrame index if datetime
        ('open', 'OPEN'),
        ('high', 'HIGH'),
        ('low', 'LOW'),
        ('close', 'CLOSE'),
        ('volume', 'VOLUME'),
        ('openinterest', -1),      # not used; set to -1

        # Map the additional columns
        ('return', 'return'),
        ('log_return', 'log_return'),
        ('hourly_volatility', 'hourly_volatility'),
        ('EMA_8', 'EMA_8'),
        ('EMA_13', 'EMA_13'),
        ('EMA_21', 'EMA_21'),
        ('EMA_signal', 'EMA_signal'),
        ('EMA_short', 'EMA_short'),
        ('EMA_long', 'EMA_long'),
        ('MACD', 'MACD'),
        ('Signal_Line', 'Signal_Line'),
        ('MACD_Hist', 'MACD_Hist'),
        ('SMA20', 'SMA20'),
        ('STD20', 'STD20'),
        ('Upper_BB', 'Upper_BB'),
        ('Lower_BB', 'Lower_BB'),
        ('RSI_14', 'RSI_14'),
    )

# Example: Load your CSV file into a pandas DataFrame.
# (Assuming your CSV has a datetime column as the index or one of the columns.)
df = pd.read_csv('../data/processed/btc_usdt_hourly_processed.csv', index_col='datetime', parse_dates=True)

# Create an instance of the custom data feed using your DataFrame.
data_feed = CustomPandasData(dataname=df)

# Now set up Cerebro and add the data feed.
cerebro = bt.Cerebro()
cerebro.addstrategy(MultiIndicatorStrategy)
cerebro.adddata(data_feed)

# (Optional) Set initial cash, commission, etc.
cerebro.broker.setcash(10000.0)
cerebro.addsizer(bt.sizers.PercentSizer, percents=10)
cerebro.broker.setcommission(commission=0.001)

print("Data feed successfully added to Cerebro!")

print("Starting Portfolio Value: {:.2f}".format(cerebro.broker.getvalue()))
# Out:
# Data feed successfully added to Cerebro!
# Starting Portfolio Value: 10000.00

# %%
cerebro.run()
print("Final Portfolio Value: {:.2f}".format(cerebro.broker.getvalue()))

#havent figured out plotting yet
cerebro.plot(style='candlestick', path='../plots/multi_indicator_strategy.png')
# Out:
# 2024-02-24 - BUY CREATE, Price: 51139.30
# 2024-02-26 - SELL CREATE, Price: 51432.92
# 2024-02-27 - BUY CREATE, Price: 56745.66
# 2024-02-29 - SELL CREATE, Price: 61374.94
# 2024-03-01 - BUY CREATE, Price: 62129.15
# 2024-03-02 - SELL CREATE, Price: 61939.64
# 2024-03-03 - BUY CREATE, Price: 62393.86
# 2024-03-05 - SELL CREATE, Price: 65575.20
# 2024-03-06 - BUY CREATE, Price: 65929.50
# 2024-03-07 - SELL CREATE, Price: 65843.57
# 2024-03-07 - BUY CREATE, Price: 66665.41
# 2024-03-10 - SELL CREATE, Price: 68418.59
# 2024-03-11 - BUY CREATE, Price: 71019.99
# 2024-03-12 - SELL CREATE, Price: 70507.37
# 2024-03-13 - BUY CREATE, Price: 71980.00
# 2024-03-14 - SELL CREATE, Price: 71884.81
# 2024-03-17 - BUY CREATE, Price: 68021.79
# 2024-03-18 - SELL CREATE, Price: 66996.69
# 2024-03-21 - BUY CREATE, Price: 66654.45
# 2024-03-21 - SELL CREATE, Price: 65133.67
# 2024-03-22 - BUY CREATE, Price: 66448.08
# 2024-03-22 - SELL CREATE, Price: 65481.99
# 2024-03-23 - BUY CREATE, Price: 64596.06
# 2024-03-24 - SELL CREATE, Price: 64470.00
# 2024-03-24 - BUY CREATE, Price: 64880.02
# 2024-03-26 - SELL CREATE, Price: 69477.67
# 2024-03-27 - BUY CREATE, Price: 70326.74
# 2024-03-27 - SELL CREATE, Price: 69547.91
# 2024-03-28 - BUY CREATE, Price: 70550.00
# 2024-03-29 - SELL CREATE, Price: 70180.70
# 2024-03-30 - BUY CREATE, Price: 70218.89
# 2024-03-30 - SELL CREATE, Price: 69812.50
# 2024-03-31 - BUY CREATE, Price: 70345.64
# 2024-04-01 - SELL CREATE, Price: 69167.48
# 2024-04-04 - BUY CREATE, Price: 66353.67
# 2024-04-05 - SELL CREATE, Price: 66930.74
# 2024-04-05 - BUY CREATE, Price: 68190.62
# 2024-04-09 - SELL CREATE, Price: 70765.69
# 2024-04-10 - BUY CREATE, Price: 70017.00
# 2024-04-11 - SELL CREATE, Price: 70011.99
# 2024-04-11 - BUY CREATE, Price: 70499.62
# 2024-04-11 - SELL CREATE, Price: 70006.23
# 2024-04-12 - BUY CREATE, Price: 70635.93
# 2024-04-12 - SELL CREATE, Price: 69270.01
# 2024-04-15 - BUY CREATE, Price: 65129.74
# 2024-04-15 - SELL CREATE, Price: 64148.61
# 2024-04-17 - BUY CREATE, Price: 64017.64
# 2024-04-17 - SELL CREATE, Price: 62898.04
# 2024-04-18 - BUY CREATE, Price: 63498.70
# 2024-04-19 - SELL CREATE, Price: 61359.58
# 2024-04-19 - BUY CREATE, Price: 64624.37
# 2024-04-20 - SELL CREATE, Price: 63656.00
# 2024-04-20 - BUY CREATE, Price: 64964.09
# 2024-04-21 - SELL CREATE, Price: 64538.00
# 2024-04-22 - BUY CREATE, Price: 64908.96
# 2024-04-22 - SELL CREATE, Price: 64658.00
# 2024-04-22 - BUY CREATE, Price: 65703.50
# 2024-04-23 - SELL CREATE, Price: 66210.74
# 2024-04-23 - BUY CREATE, Price: 66909.78
# 2024-04-24 - SELL CREATE, Price: 66353.02
# 2024-04-28 - BUY CREATE, Price: 63603.60
# 2024-04-28 - SELL CREATE, Price: 63151.05
# 2024-04-29 - BUY CREATE, Price: 63890.00
# 2024-04-30 - SELL CREATE, Price: 61919.32
# 2024-05-02 - BUY CREATE, Price: 58727.45
# 2024-05-06 - SELL CREATE, Price: 63271.97
# 2024-05-07 - BUY CREATE, Price: 64119.98
# 2024-05-07 - SELL CREATE, Price: 63213.16
# 2024-05-07 - BUY CREATE, Price: 64024.47
# 2024-05-07 - SELL CREATE, Price: 63391.79
# 2024-05-09 - BUY CREATE, Price: 62454.92
# 2024-05-10 - SELL CREATE, Price: 61063.87
# 2024-05-12 - BUY CREATE, Price: 61155.75
# 2024-05-13 - SELL CREATE, Price: 60976.96
# 2024-05-13 - BUY CREATE, Price: 62334.37
# 2024-05-14 - SELL CREATE, Price: 62042.00
# 2024-05-15 - BUY CREATE, Price: 62467.18
# 2024-05-16 - SELL CREATE, Price: 65122.18
# 2024-05-17 - BUY CREATE, Price: 65955.56
# 2024-05-19 - SELL CREATE, Price: 66889.88
# 2024-05-20 - BUY CREATE, Price: 67109.99
# 2024-05-21 - SELL CREATE, Price: 69285.99
# 2024-05-22 - BUY CREATE, Price: 70455.90
# 2024-05-22 - SELL CREATE, Price: 69574.60
# 2024-05-24 - BUY CREATE, Price: 68970.43
# 2024-05-26 - SELL CREATE, Price: 68808.62
# 2024-05-27 - BUY CREATE, Price: 70161.22
# 2024-05-28 - SELL CREATE, Price: 68680.00
# 2024-05-29 - BUY CREATE, Price: 68829.42
# 2024-05-29 - SELL CREATE, Price: 67872.41
# 2024-05-30 - BUY CREATE, Price: 68623.99
# 2024-05-31 - SELL CREATE, Price: 68136.00
# 2024-06-02 - BUY CREATE, Price: 67755.00
# 2024-06-02 - SELL CREATE, Price: 67529.99
# 2024-06-02 - BUY CREATE, Price: 68251.52
# 2024-06-02 - SELL CREATE, Price: 67765.63
# 2024-06-03 - BUY CREATE, Price: 68476.01
# 2024-06-04 - SELL CREATE, Price: 68836.54
# 2024-06-04 - BUY CREATE, Price: 69527.99
# 2024-06-06 - SELL CREATE, Price: 70904.01
# 2024-06-06 - BUY CREATE, Price: 71187.17
# 2024-06-06 - SELL CREATE, Price: 70479.49
# 2024-06-07 - BUY CREATE, Price: 71290.60
# 2024-06-07 - SELL CREATE, Price: 69803.59
# 2024-06-09 - BUY CREATE, Price: 69622.88
# 2024-06-10 - SELL CREATE, Price: 69303.99
# 2024-06-10 - BUY CREATE, Price: 70066.12
# 2024-06-10 - SELL CREATE, Price: 69540.00
# 2024-06-12 - BUY CREATE, Price: 68828.01
# 2024-06-13 - SELL CREATE, Price: 67734.81
# 2024-06-16 - BUY CREATE, Price: 66409.97
# 2024-06-17 - SELL CREATE, Price: 66222.00
# 2024-06-17 - BUY CREATE, Price: 66691.99
# 2024-06-18 - SELL CREATE, Price: 65133.99
# 2024-06-20 - BUY CREATE, Price: 65465.24
# 2024-06-20 - SELL CREATE, Price: 64831.23
# 2024-06-23 - BUY CREATE, Price: 64476.43
# 2024-06-23 - SELL CREATE, Price: 64297.79
# 2024-06-25 - BUY CREATE, Price: 61810.00
# 2024-06-26 - SELL CREATE, Price: 61376.73
# 2024-06-27 - BUY CREATE, Price: 61729.99
# 2024-06-28 - SELL CREATE, Price: 61395.09
# 2024-06-29 - BUY CREATE, Price: 61106.00
# 2024-06-30 - SELL CREATE, Price: 60834.27
# 2024-06-30 - BUY CREATE, Price: 61528.01
# 2024-07-02 - SELL CREATE, Price: 62629.99
# 2024-07-06 - BUY CREATE, Price: 56557.81
# 2024-07-07 - SELL CREATE, Price: 57341.09
# 2024-07-08 - BUY CREATE, Price: 57151.11
# 2024-07-08 - SELL CREATE, Price: 55812.00
# 2024-07-09 - BUY CREATE, Price: 57261.90
# 2024-07-10 - SELL CREATE, Price: 57699.69
# 2024-07-11 - BUY CREATE, Price: 58191.50
# 2024-07-11 - SELL CREATE, Price: 57640.84
# 2024-07-12 - BUY CREATE, Price: 58116.01
# 2024-07-17 - SELL CREATE, Price: 64242.00
# 2024-07-18 - BUY CREATE, Price: 65000.01
# 2024-07-18 - SELL CREATE, Price: 63995.40
# 2024-07-19 - BUY CREATE, Price: 65135.90
# 2024-07-21 - SELL CREATE, Price: 66760.01
# 2024-07-21 - BUY CREATE, Price: 67290.76
# 2024-07-22 - SELL CREATE, Price: 67422.01
# 2024-07-22 - BUY CREATE, Price: 68232.07
# 2024-07-23 - SELL CREATE, Price: 66936.00
# 2024-07-24 - BUY CREATE, Price: 66586.01
# 2024-07-24 - SELL CREATE, Price: 65652.00
# 2024-07-25 - BUY CREATE, Price: 65644.00
# 2024-07-28 - SELL CREATE, Price: 67940.95
# 2024-07-28 - BUY CREATE, Price: 68112.00
# 2024-07-29 - SELL CREATE, Price: 66940.01
# 2024-08-02 - BUY CREATE, Price: 64660.01
# 2024-08-02 - SELL CREATE, Price: 63157.95
# 2024-08-06 - BUY CREATE, Price: 55493.98
# 2024-08-07 - SELL CREATE, Price: 56125.47
# 2024-08-08 - BUY CREATE, Price: 57049.74
# 2024-08-11 - SELL CREATE, Price: 60492.09
# 2024-08-13 - BUY CREATE, Price: 59740.00
# 2024-08-13 - SELL CREATE, Price: 59099.98
# 2024-08-13 - BUY CREATE, Price: 59472.26
# 2024-08-14 - SELL CREATE, Price: 59502.67
# 2024-08-16 - BUY CREATE, Price: 59215.85
# 2024-08-18 - SELL CREATE, Price: 59350.00
# 2024-08-19 - BUY CREATE, Price: 59241.00
# 2024-08-20 - SELL CREATE, Price: 58801.15
# 2024-08-21 - BUY CREATE, Price: 59885.58
# 2024-08-22 - SELL CREATE, Price: 60164.70
# 2024-08-23 - BUY CREATE, Price: 60625.70
# 2024-08-25 - SELL CREATE, Price: 63881.01
# 2024-08-25 - BUY CREATE, Price: 64148.01
# 2024-08-26 - SELL CREATE, Price: 63950.01
# 2024-08-29 - BUY CREATE, Price: 59161.00
# 2024-08-29 - SELL CREATE, Price: 59496.00
# 2024-09-02 - BUY CREATE, Price: 58181.22
# 2024-09-03 - SELL CREATE, Price: 57672.84
# 2024-09-04 - BUY CREATE, Price: 58100.00
# 2024-09-05 - SELL CREATE, Price: 57194.99
# 2024-09-08 - BUY CREATE, Price: 54608.01
# 2024-09-08 - SELL CREATE, Price: 54149.50
# 2024-09-08 - BUY CREATE, Price: 54530.00
# 2024-09-11 - SELL CREATE, Price: 56530.50
# 2024-09-11 - BUY CREATE, Price: 57694.00
# 2024-09-13 - SELL CREATE, Price: 57767.01
# 2024-09-13 - BUY CREATE, Price: 58343.99
# 2024-09-15 - SELL CREATE, Price: 59971.09
# 2024-09-17 - BUY CREATE, Price: 58966.48
# 2024-09-18 - SELL CREATE, Price: 59508.50
# 2024-09-18 - BUY CREATE, Price: 60629.79
# 2024-09-20 - SELL CREATE, Price: 62704.00
# 2024-09-21 - BUY CREATE, Price: 63089.77
# 2024-09-22 - SELL CREATE, Price: 62957.31
# 2024-09-22 - BUY CREATE, Price: 63881.51
# 2024-09-23 - SELL CREATE, Price: 63394.50
# 2024-09-24 - BUY CREATE, Price: 63851.05
# 2024-09-24 - SELL CREATE, Price: 63159.99
# 2024-09-24 - BUY CREATE, Price: 63775.86
# 2024-09-25 - SELL CREATE, Price: 63630.45
# 2024-09-26 - BUY CREATE, Price: 63798.00
# 2024-09-28 - SELL CREATE, Price: 65548.12
# 2024-09-28 - BUY CREATE, Price: 65858.00
# 2024-09-29 - SELL CREATE, Price: 65499.99
# 2024-09-29 - BUY CREATE, Price: 65751.34
# 2024-09-30 - SELL CREATE, Price: 65463.85
# 2024-10-04 - BUY CREATE, Price: 61224.34
# 2024-10-05 - SELL CREATE, Price: 61848.48
# 2024-10-06 - BUY CREATE, Price: 62066.38
# 2024-10-07 - SELL CREATE, Price: 62471.08
# 2024-10-12 - BUY CREATE, Price: 62554.97
# 2024-10-13 - SELL CREATE, Price: 62843.48
# 2024-10-15 - BUY CREATE, Price: 65929.99
# 2024-10-17 - SELL CREATE, Price: 67162.87
# 2024-10-18 - BUY CREATE, Price: 68085.50
# 2024-10-19 - SELL CREATE, Price: 68222.00
# 2024-10-19 - BUY CREATE, Price: 68378.00
# 2024-10-20 - SELL CREATE, Price: 68158.00
# 2024-10-20 - BUY CREATE, Price: 68378.00
# 2024-10-21 - SELL CREATE, Price: 68301.46
# 2024-10-24 - BUY CREATE, Price: 67459.63
# 2024-10-25 - SELL CREATE, Price: 66836.01
# 2024-10-27 - BUY CREATE, Price: 67181.82
# 2024-10-30 - SELL CREATE, Price: 71894.72
# 2024-10-30 - BUY CREATE, Price: 72857.14
# 2024-10-31 - SELL CREATE, Price: 71308.00
# 2024-11-04 - BUY CREATE, Price: 69305.56
# 2024-11-04 - SELL CREATE, Price: 68394.01
# 2024-11-05 - BUY CREATE, Price: 68893.99
# 2024-11-09 - SELL CREATE, Price: 76087.18
# 2024-11-09 - BUY CREATE, Price: 76519.90
# 2024-11-13 - SELL CREATE, Price: 86545.99
# 2024-11-13 - BUY CREATE, Price: 89152.01
# 2024-11-14 - SELL CREATE, Price: 87947.99
# 2024-11-15 - BUY CREATE, Price: 89107.98
# 2024-11-16 - SELL CREATE, Price: 90328.39
# 2024-11-17 - BUY CREATE, Price: 91295.24
# 2024-11-17 - SELL CREATE, Price: 90310.91
# 2024-11-18 - BUY CREATE, Price: 92061.84
# 2024-11-18 - SELL CREATE, Price: 89502.23
# 2024-11-18 - BUY CREATE, Price: 92309.51
# 2024-11-23 - SELL CREATE, Price: 98449.07
# 2024-11-25 - BUY CREATE, Price: 98082.86
# 2024-11-25 - SELL CREATE, Price: 95385.49
# 2024-11-28 - BUY CREATE, Price: 95699.79
# 2024-11-28 - SELL CREATE, Price: 94972.00
# 2024-11-28 - BUY CREATE, Price: 95643.98
# 2024-11-30 - SELL CREATE, Price: 96639.66
# 2024-11-30 - BUY CREATE, Price: 96966.37
# 2024-11-30 - SELL CREATE, Price: 96407.99
# 2024-12-01 - BUY CREATE, Price: 97030.15
# 2024-12-02 - SELL CREATE, Price: 96359.99
# 2024-12-03 - BUY CREATE, Price: 95849.69
# 2024-12-04 - SELL CREATE, Price: 94847.81
# 2024-12-04 - BUY CREATE, Price: 97209.64
# 2024-12-05 - SELL CREATE, Price: 99072.84
# 2024-12-06 - BUY CREATE, Price: 100372.01
# 2024-12-07 - SELL CREATE, Price: 99336.27
# 2024-12-07 - BUY CREATE, Price: 100123.32
# 2024-12-08 - SELL CREATE, Price: 99675.11
# 2024-12-08 - BUY CREATE, Price: 100408.80
# 2024-12-09 - SELL CREATE, Price: 99195.89
# 2024-12-11 - BUY CREATE, Price: 97689.57
# 2024-12-12 - SELL CREATE, Price: 99760.01
# 2024-12-13 - BUY CREATE, Price: 101018.12
# 2024-12-14 - SELL CREATE, Price: 100895.98
# 2024-12-15 - BUY CREATE, Price: 102134.48
# 2024-12-17 - SELL CREATE, Price: 105972.01
# 2024-12-21 - BUY CREATE, Price: 98691.98
# 2024-12-21 - SELL CREATE, Price: 97292.00
# 2024-12-24 - BUY CREATE, Price: 97581.09
# 2024-12-26 - SELL CREATE, Price: 97719.99
# 2024-12-28 - BUY CREATE, Price: 95300.00
# 2024-12-29 - SELL CREATE, Price: 94623.67
# 2024-12-31 - BUY CREATE, Price: 94113.69
# 2024-12-31 - SELL CREATE, Price: 93576.00
# 2025-01-01 - BUY CREATE, Price: 94432.94
# 2025-01-03 - SELL CREATE, Price: 96129.97
# 2025-01-03 - BUY CREATE, Price: 97016.01
# 2025-01-05 - SELL CREATE, Price: 97652.20
# 2025-01-05 - BUY CREATE, Price: 98275.71
# 2025-01-07 - SELL CREATE, Price: 100636.80
# 2025-01-10 - BUY CREATE, Price: 93557.23
# 2025-01-11 - SELL CREATE, Price: 94216.25
# 2025-01-11 - BUY CREATE, Price: 94625.65
# 2025-01-11 - SELL CREATE, Price: 94151.52
# 2025-01-11 - BUY CREATE, Price: 94940.76
# 2025-01-12 - SELL CREATE, Price: 94323.85
# 2025-01-12 - BUY CREATE, Price: 94811.00
# 2025-01-12 - SELL CREATE, Price: 93962.91
# 2025-01-13 - BUY CREATE, Price: 95325.43
# 2025-01-13 - SELL CREATE, Price: 94217.43
# 2025-01-14 - BUY CREATE, Price: 95988.00
# 2025-01-16 - SELL CREATE, Price: 97618.89
# 2025-01-16 - BUY CREATE, Price: 99838.54
# 2025-01-18 - SELL CREATE, Price: 103184.64
# 2025-01-18 - BUY CREATE, Price: 104365.81
# 2025-01-19 - SELL CREATE, Price: 103414.00
# 2025-01-20 - BUY CREATE, Price: 107120.65
# 2025-01-20 - SELL CREATE, Price: 103691.63
# 2025-01-21 - BUY CREATE, Price: 104965.99
# 2025-01-22 - SELL CREATE, Price: 104073.94
# 2025-01-23 - BUY CREATE, Price: 105139.18
# 2025-01-24 - SELL CREATE, Price: 103016.01
# 2025-01-24 - BUY CREATE, Price: 104631.99
# 2025-01-25 - SELL CREATE, Price: 104419.59
# 2025-01-25 - BUY CREATE, Price: 104983.49
# 2025-01-26 - SELL CREATE, Price: 104621.37
# 2025-01-26 - BUY CREATE, Price: 105062.42
# 2025-01-26 - SELL CREATE, Price: 104715.29
# 2025-01-26 - BUY CREATE, Price: 104961.73
# 2025-01-26 - SELL CREATE, Price: 104557.19
# 2025-01-28 - BUY CREATE, Price: 102636.32
# 2025-01-28 - SELL CREATE, Price: 101264.48
# 2025-01-29 - BUY CREATE, Price: 102801.64
# 2025-01-29 - SELL CREATE, Price: 102092.01
# 2025-01-29 - BUY CREATE, Price: 102406.98
# 2025-01-31 - SELL CREATE, Price: 104341.72
# 2025-01-31 - BUY CREATE, Price: 105464.01
# 2025-01-31 - SELL CREATE, Price: 102627.29
# 2025-02-04 - BUY CREATE, Price: 100053.12
# 2025-02-04 - SELL CREATE, Price: 98779.91
# 2025-02-06 - BUY CREATE, Price: 98614.41
# 2025-02-06 - SELL CREATE, Price: 96586.96
# 2025-02-07 - BUY CREATE, Price: 97963.58
# 2025-02-07 - SELL CREATE, Price: 95764.31
# 2025-02-09 - BUY CREATE, Price: 96727.31
# 2025-02-09 - SELL CREATE, Price: 95877.92
# 2025-02-10 - BUY CREATE, Price: 97015.26
# 2025-02-11 - SELL CREATE, Price: 96962.03
# 2025-02-12 - BUY CREATE, Price: 96921.43
# 2025-02-13 - SELL CREATE, Price: 96070.23
# 2025-02-14 - BUY CREATE, Price: 96528.47
# 2025-02-16 - SELL CREATE, Price: 97248.98
# 2025-02-19 - BUY CREATE, Price: 96166.44
# 2025-02-21 - SELL CREATE, Price: 96971.90
# 2025-03-01 - BUY CREATE, Price: 85588.19
# 2025-03-03 - SELL CREATE, Price: 90035.37
# Final Portfolio Value: 10171.32
# <div id='bfb26c11-33fb-46a1-90ee-a322e0543629'></div>
# [[<Figure size 640x480 with 4 Axes>]]
